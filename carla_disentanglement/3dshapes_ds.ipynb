# %%
from carla_disentanglement.datasets.shapes import Shapes3DDataset
import numpy as np

# %%
ds = Shapes3DDataset()

# %%
for i in range(ds.num_factors):
    print(ds.labels[:,i].unique())
# Out:
# tensor([0.0000, 0.1000, 0.2000, 0.3000, 0.4000, 0.5000, 0.6000, 0.7000, 0.8000,
#         0.9000], dtype=torch.float64)
# tensor([0.0000, 0.1000, 0.2000, 0.3000, 0.4000, 0.5000, 0.6000, 0.7000, 0.8000,
#         0.9000], dtype=torch.float64)
# tensor([0.0000, 0.1000, 0.2000, 0.3000, 0.4000, 0.5000, 0.6000, 0.7000, 0.8000,
#         0.9000], dtype=torch.float64)
# tensor([0.7500, 0.8214, 0.8929, 0.9643, 1.0357, 1.1071, 1.1786, 1.2500],
#        dtype=torch.float64)
# tensor([0., 1., 2., 3.], dtype=torch.float64)
# tensor([-30.0000, -25.7143, -21.4286, -17.1429, -12.8571,  -8.5714,  -4.2857,
#           0.0000,   4.2857,   8.5714,  12.8571,  17.1429,  21.4286,  25.7143,
#          30.0000], dtype=torch.float64)

# %%
import matplotlib.pyplot as plt

# %%
ds.labels[0:2].numpy()
# Out:
# array([[  0.        ,   0.        ,   0.        ,   0.75      ,
#           0.        , -30.        ],
#        [  0.        ,   0.        ,   0.        ,   0.75      ,
#           0.        , -25.71428571]])

# %%
plt.imshow(ds.data[0].permute(1,2,0), interpolation='nearest')
plt.show()

# %%
r = np.random.RandomState(0)
f = ds.sample_factors(2, r)
f
# Out:
# array([[5, 3, 7, 3, 2, 7],
#        [0, 3, 9, 5, 0, 6]], dtype=int64)

# %%
ofromf = ds.sample_observations_from_factors(np.array([[0, 0, 0, 0, 0, 0],
       [0, 3, 9, 5, 0, 6]]), r)

# %%
plt.imshow(ofromf[0].permute(1,2,0), interpolation='nearest')
plt.show()
plt.imshow(ofromf[1].permute(1,2,0), interpolation='nearest')
plt.show()
